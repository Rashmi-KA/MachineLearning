# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
print (filename)
#import the dataset
df_credit = pd.read_csv('/kaggle/input/default-of-credit-card-clients/default of credit card clients.csv')
# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/default-of-credit-card-clients/default of credit card clients.csv
# default of credit card clients.csv

# %%
#Information on the dataset
df_credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID           30000 non-null int64
# LIMIT_BAL    30000 non-null int64
# SEX          30000 non-null int64
# EDUCATION    30000 non-null int64
# MARRIAGE     30000 non-null int64
# AGE          30000 non-null int64
# PAY_1        30000 non-null int64
# PAY_2        30000 non-null int64
# PAY_3        30000 non-null int64
# PAY_4        30000 non-null int64
# PAY_5        30000 non-null int64
# PAY_6        30000 non-null int64
# BILL_AMT1    30000 non-null int64
# BILL_AMT2    30000 non-null int64
# BILL_AMT3    30000 non-null int64
# BILL_AMT4    30000 non-null int64
# BILL_AMT5    30000 non-null int64
# BILL_AMT6    30000 non-null int64
# PAY_AMT1     30000 non-null int64
# PAY_AMT2     30000 non-null int64
# PAY_AMT3     30000 non-null int64
# PAY_AMT4     30000 non-null int64
# PAY_AMT5     30000 non-null int64
# PAY_AMT6     30000 non-null int64
# ...

# %%
#Print the size of the dataset
print(df_credit.shape)
#validate for null values
df_credit.isna().sum()
#There are no null values
# Out:
# (30000, 25)
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_1        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# dpnm         0
# dtype: int64

# %%
#Check for duplicate values and remove the same if any
print('The duplicated data are',df_credit.duplicated().sum())
# Out:
# The duplicated data are 0

# %%
#lets check for corelation of the features
df_credit.corr()
# Out:
#                  ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE  \
# ID         1.000000   0.026179  0.018497   0.039177 -0.029079  0.018678
# LIMIT_BAL  0.026179   1.000000  0.024755  -0.219161 -0.108139  0.144713
# SEX        0.018497   0.024755  1.000000   0.014232 -0.031389 -0.090874
# EDUCATION  0.039177  -0.219161  0.014232   1.000000 -0.143464  0.175061
# MARRIAGE  -0.029079  -0.108139 -0.031389  -0.143464  1.000000 -0.414170
# AGE        0.018678   0.144713 -0.090874   0.175061 -0.414170  1.000000
# PAY_1     -0.030575  -0.271214 -0.057643   0.105364  0.019917 -0.039447
# PAY_2     -0.011215  -0.296382 -0.070771   0.121566  0.024199 -0.050148
# PAY_3     -0.018494  -0.286123 -0.066096   0.114025  0.032688 -0.053048
# PAY_4     -0.002735  -0.267460 -0.060173   0.108793  0.033122 -0.049722
# PAY_5     -0.022199  -0.249411 -0.055064   0.097520  0.035629 -0.053826
# PAY_6     -0.020270  -0.235195 -0.044008   0.082316  0.034345 -0.048773
# ...

# %%
#Lets divide the data ino feature set and output
#Lets drop ID colomn 
X = df_credit.drop(['dpnm','ID'],axis=1)
y = df_credit['dpnm']
#Split the data into train and test
#lets standardized the data
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=67)

Std = StandardScaler()
X_train = Std.fit_transform(X_train)
X_test = Std.transform(X_test)

# %%
#implementation of logistic Regression
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = LR.predict(X_test)
#Validate the accuracy score
### Metrics ###
from sklearn import metrics
from sklearn.metrics import f1_score,confusion_matrix
import seaborn as sns
Accuracy = LR.score(X_test,y_test)
#print Accuracy
print('Accuracy of the Logistic Regression is',Accuracy)
#print confusion metrics
CM = confusion_matrix(y_pred,y_test)
sns.heatmap(CM, annot=True, cbar=False, cmap='twilight',linewidth=0.5,fmt='d')
# Out:
# Accuracy of the Logistic Regression is 0.8071666666666667

# %%
#lets implement Naive Bayes here
from sklearn.naive_bayes import GaussianNB
X_train_GB, X_test_GB, y_train_GB, y_test_GB = train_test_split(X, y, test_size=0.2, random_state=88)
Std = StandardScaler()
X_train_GB = Std.fit_transform(X_train)
X_test_GB = Std.transform(X_test)
#Create a Gaussian Classifier
gnb = GaussianNB()

#Train the model using the training sets
gnb.fit(X_train_GB, y_train_GB)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
#Predict the response for test dataset
y_pred_GB = gnb.predict(X_test_GB)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_pred_GB, y_test_GB))
#print confusion metrics
CM = confusion_matrix(y_pred,y_test)
sns.heatmap(CM, annot=True, cbar=False, cmap='twilight',linewidth=0.5,fmt='d')
# Out:
# Accuracy: 0.6986666666666667
